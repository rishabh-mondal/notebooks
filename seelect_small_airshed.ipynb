# %%
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
from shapely.geometry import box

# Load airshed data
airshed_path = "/home/patel_zeel/kiln_compass_24/regions/shapes/delhi_airshed.geojson"
gdf_airshed = gpd.read_file(airshed_path)

# Save original CRS (EPSG:4326)
original_crs = gdf_airshed.crs

# Reproject to Equal-Area CRS (EPSG:6933)
gdf_airshed_m = gdf_airshed.to_crs("EPSG:6933")

# Get bounding box in meters
minx, miny, maxx, maxy = gdf_airshed_m.total_bounds

# Divide into 8 equal parts (4 columns × 2 rows)
rows, cols = 2, 4
x_split = np.linspace(minx, maxx, cols + 1)
y_split = np.linspace(miny, maxy, rows + 1)

# Create grid cells
grid_cells = []
for i in range(cols):
    for j in range(rows):
        cell = box(x_split[i], y_split[j], x_split[i+1], y_split[j+1])
        grid_cells.append(cell)

# Convert grid to GeoDataFrame and clip with the airshed
grid_gdf = gpd.GeoDataFrame(geometry=grid_cells, crs="EPSG:6933")
grid_gdf = gpd.overlay(grid_gdf, gdf_airshed_m, how="intersection")

# Convert back to original CRS
grid_gdf = grid_gdf.to_crs(original_crs)
gdf_airshed = gdf_airshed.to_crs(original_crs)

# Select the **third grid cell in the upper row** (index 2 in row 0)
selected_grid = grid_gdf.iloc[[5]]  # Keep as GeoDataFrame

# Get centroid of selected grid cell
selected_centroid = selected_grid.geometry.centroid.iloc[0]

# Plot
fig, ax = plt.subplots(figsize=(10, 8))

# Plot airshed
gdf_airshed.plot(ax=ax, edgecolor="black", facecolor="lightgray", alpha=0.5, label="Delhi Airshed")

# Plot grid in green
grid_gdf.boundary.plot(ax=ax, color="green", linewidth=1.5, linestyle="--", label="Grid")

# Highlight the selected grid cell in blue
selected_grid.plot(ax=ax, facecolor="blue", edgecolor="black", alpha=0.4, label="Selected Grid")

# Mark the centroid
ax.scatter(selected_centroid.x, selected_centroid.y, color="red", marker="o", s=100, label="Selected Grid Centroid")

# Customize plot
ax.set_title("Delhi Airshed with Selected Upper Third Grid Cell", fontsize=14)
ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")
plt.legend()
plt.show()

# Define output GeoJSON path
output_geojson_path = "/home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/regions/delhi_ncr_small.geojson"

# Save the selected grid cell as a GeoJSON file
selected_grid.to_file(output_geojson_path, driver="GeoJSON")

print(f"Selected grid saved as GeoJSON: {output_geojson_path}")
# Out:
# /tmp/ipykernel_1087425/2886978205.py:43: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   selected_centroid = selected_grid.geometry.centroid.iloc[0]
# /tmp/ipykernel_1087425/2886978205.py:64: UserWarning: Legend does not support handles for PatchCollection instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   plt.legend()
# Selected grid saved as GeoJSON: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/regions/delhi_ncr_small.geojson

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import box
import numpy as np

# Load GeoJSONs (EPSG:4326)
airshed_path = "/home/patel_zeel/kiln_compass_24/regions/shapes/delhi_airshed.geojson"
ncr_data_path = "/home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/hand_validation_annotated/ncr_kilns.geojson"

gdf_airshed = gpd.read_file(airshed_path)
gdf_ncr = gpd.read_file(ncr_data_path)

# Reproject to Equal-Area CRS (World Equidistant Cylindrical EPSG:6933)
gdf_airshed_m = gdf_airshed.to_crs("EPSG:6933")

# Get bounding box in meters
minx, miny, maxx, maxy = gdf_airshed_m.total_bounds

# Divide into 8 equal parts (4 columns × 2 rows)
rows, cols = 2, 4
x_split = np.linspace(minx, maxx, cols + 1)
y_split = np.linspace(miny, maxy, rows + 1)

# Create grid cells
grid_cells = []
for i in range(cols):
    for j in range(rows):
        cell = box(x_split[i], y_split[j], x_split[i+1], y_split[j+1])
        grid_cells.append(cell)

# Convert to GeoDataFrame and clip grid to the airshed
grid_gdf = gpd.GeoDataFrame(geometry=grid_cells, crs="EPSG:6933")
grid_gdf = gpd.overlay(grid_gdf, gdf_airshed_m, how="intersection")

# Convert back to EPSG:4326 for plotting
grid_gdf = grid_gdf.to_crs("EPSG:4326")
gdf_airshed = gdf_airshed.to_crs("EPSG:4326")

# Clip kilns data to the airshed
gdf_ncr_clipped = gpd.overlay(gdf_ncr, gdf_airshed, how="intersection")

# Create plot
fig, ax = plt.subplots(figsize=(10, 8))

# Plot Delhi Airshed
gdf_airshed.plot(ax=ax, edgecolor="black", facecolor="lightgray", alpha=0.5, label="Delhi Airshed")

# Plot Clipped Grid in Green
grid_gdf.boundary.plot(ax=ax, color="green", linewidth=1.5, linestyle="--", label="Grid Inside Airshed")
gdf_ncr_clipped["centroid"] = gdf_ncr_clipped.geometry.centroid
ax.scatter(gdf_ncr_clipped.centroid.x, gdf_ncr_clipped.centroid.y, 
           color="red", s=10, edgecolor="black", linewidth=0.5, label="Kilns Inside Airshed")


# Customize plot
ax.set_title("Delhi Airshed with Grid and Kilns", fontsize=14)
ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")
plt.legend()

plt.show()
# Out:
# /tmp/ipykernel_1087425/227090387.py:50: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_ncr_clipped["centroid"] = gdf_ncr_clipped.geometry.centroid
# /tmp/ipykernel_1087425/227090387.py:51: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   ax.scatter(gdf_ncr_clipped.centroid.x, gdf_ncr_clipped.centroid.y,
# /tmp/ipykernel_1087425/227090387.py:59: UserWarning: Legend does not support handles for PatchCollection instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   plt.legend()

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import box
import numpy as np

# Load GeoJSONs (EPSG:4326)
airshed_path = "/home/patel_zeel/kiln_compass_24/regions/shapes/delhi_airshed.geojson"
ncr_data_path = "/home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/hand_validation_annotated/ncr_kilns.geojson"

gdf_airshed = gpd.read_file(airshed_path)
gdf_ncr = gpd.read_file(ncr_data_path)

# Reproject to Equal-Area CRS (World Equidistant Cylindrical EPSG:6933)
gdf_airshed_m = gdf_airshed.to_crs("EPSG:6933")

# Get bounding box in meters
minx, miny, maxx, maxy = gdf_airshed_m.total_bounds

# Divide into 8 equal parts (4 columns × 2 rows)
rows, cols = 2, 4
x_split = np.linspace(minx, maxx, cols + 1)
y_split = np.linspace(miny, maxy, rows + 1)

# Create grid cells
grid_cells = []
for i in range(cols):
    for j in range(rows):
        cell = box(x_split[i], y_split[j], x_split[i+1], y_split[j+1])
        grid_cells.append(cell)

# Convert to GeoDataFrame and clip grid to the airshed
grid_gdf = gpd.GeoDataFrame(geometry=grid_cells, crs="EPSG:6933")
grid_gdf = gpd.overlay(grid_gdf, gdf_airshed_m, how="intersection")

# Calculate area of each clipped grid cell (in km²)
grid_gdf["area_km2"] = grid_gdf.area / 1e6  # Convert from m² to km²

# Convert back to EPSG:4326 for plotting
grid_gdf = grid_gdf.to_crs("EPSG:4326")
gdf_airshed = gdf_airshed.to_crs("EPSG:4326")

# Clip kilns data to the airshed
gdf_ncr_clipped = gpd.overlay(gdf_ncr, gdf_airshed, how="intersection")

# Get centroids for labeling each grid cell
grid_gdf["centroid"] = grid_gdf.geometry.centroid

# Identify the 5th grid cell (Index 4 in zero-based indexing)
grid_5th = grid_gdf.iloc[5]

# Create plot
fig, ax = plt.subplots(figsize=(10, 8))

# Plot Delhi Airshed
gdf_airshed.plot(ax=ax, edgecolor="black", facecolor="lightgray", alpha=0.5, label="Delhi Airshed")

# Plot Clipped Grid in Green
grid_gdf.boundary.plot(ax=ax, color="green", linewidth=1.5, linestyle="--", label="Grid Inside Airshed")

# Highlight the 5th grid cell in blue
gpd.GeoDataFrame([grid_5th], geometry="geometry").plot(ax=ax, color="blue", alpha=0.3, edgecolor="blue", linewidth=2, label="5th Grid Cell")

# Mark the centroid of the 5th grid cell
ax.scatter(grid_5th.centroid.x, grid_5th.centroid.y, color="blue", s=100, marker="*", edgecolor="black", linewidth=1.5, label="5th Grid Centroid")

# Plot Kilns
gdf_ncr_clipped["centroid"] = gdf_ncr_clipped.geometry.centroid
ax.scatter(gdf_ncr_clipped.centroid.x, gdf_ncr_clipped.centroid.y, 
           color="red", s=10, edgecolor="black", linewidth=0.5, label="Kilns Inside Airshed")

# Display the area of each grid cell on the plot
for idx, row in grid_gdf.iterrows():
    centroid = row["centroid"]
    ax.text(centroid.x, centroid.y, f"{row['area_km2']:.2f} km²", 
            fontsize=10, ha="center", va="center", 
            bbox=dict(facecolor='white', alpha=0.5, edgecolor='black'))

# Add annotation for 5th grid cell
ax.annotate("5th Grid Cell", xy=(grid_5th.centroid.x, grid_5th.centroid.y), 
            xytext=(grid_5th.centroid.x + 0.1, grid_5th.centroid.y + 0.1),
            arrowprops=dict(facecolor='blue', arrowstyle="->"), fontsize=12, color="blue")

# Customize plot
ax.set_title("Delhi Airshed with Highlighted 5th Grid Cell", fontsize=14)
ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")
plt.legend()

plt.show();
# Out:
# /tmp/ipykernel_1087425/1672317898.py:46: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   grid_gdf["centroid"] = grid_gdf.geometry.centroid
# /tmp/ipykernel_1087425/1672317898.py:67: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_ncr_clipped["centroid"] = gdf_ncr_clipped.geometry.centroid
# /tmp/ipykernel_1087425/1672317898.py:68: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   ax.scatter(gdf_ncr_clipped.centroid.x, gdf_ncr_clipped.centroid.y,
# /tmp/ipykernel_1087425/1672317898.py:87: UserWarning: Legend does not support handles for PatchCollection instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   plt.legend()
