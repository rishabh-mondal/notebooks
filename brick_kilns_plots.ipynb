# %%
import os 


# Basic
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Monitoring
from tqdm.notebook import tqdm

# IO
from os.path import join, exists, basename, dirname, splitext, expanduser
from glob import glob

# Parallel processing
from joblib import Parallel, delayed
import geopandas as gpd

from astra.plot.utils import latexify
import leafmap
# m = leafmap.Map()
# m.add_basemap("HYBRID")
# m.add_gdf(shape_gdf, zoom_to_layer=True)
# m

# %%
###kabul data plot
path="/home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/raw_data/raw_shapefile/ne_110m_admin_0_countries/ne_110m_admin_0_countries.shp"
gdf = gpd.read_file(path).to_crs(epsg=4326)
gdf_c = gdf[gdf['ADMIN'] == 'Pakistan']
#plot line plot
fig, ax = plt.subplots(figsize=(5, 5))
gdf_c.boundary.plot(ax=ax)
# Out:
# <Axes: >

# %%
###kabul data plot
path="/home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/raw_data/pakistan_dataset/Brick_Kilns_IGP_PK.shp"
gdf = gpd.read_file(path).to_crs(epsg=4326)
# gdf.crs
# gdf['KilnType'].value_counts().plot(kind='bar')
## plot in leafmap

# %%
gdf['geometry'] 
#selcting only pakisthan coordinates and plot
xpakistan_bounds = gdf[gdf.geometry.bounds.minx.between(60, 78) & gdf.geometry.bounds.miny.between(23, 38)]
xpakistan_bounds
xpakistan_bounds['geometry']
# m = leafmap.Map()
# m.add_basemap("HYBRID")
# m.add_gdf(xpakistan_bounds, zoom_to_layer=True)
# m
#plot the geometry data with pakistan map not in lafmap
fig, ax = plt.subplots(figsize=(5, 5))
gdf_c.boundary.plot(ax=ax)
xpakistan_bounds.plot(ax=ax, color='red')
plt.show()

#make a kml file for the same
xpakistan_bounds.to_file("pakistan_kilns.kml", driver='KML')

# xpakistan_bounds.plot()

# %%
shapefile_path="/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/albk_v2/YOLO_LOCALIZATION/shapefiles/india_districtwise_shapefile_2022/DISTRICT_BOUNDARY.shp"

df = gpd.read_file(shapefile_path).to_crs(epsg=4326)

# %%
display(df.head())
# Out:
#           District    STATE REMARKS  State_LGD DISTRICT_L     Shape_Leng  \
# 0            MORBI  GUJAR>T    None         24        673  539476.764723
# 1        AHMAD>B>D  GUJAR>T    None         24        438  857254.094647
# 2            >NAND  GUJAR>T    None         24        440  393046.690523
# 3  DEVBHUMI DW>RKA  GUJAR>T    None         24        674  661732.986530
# 4         J>MNAGAR  GUJAR>T    None         24        447  737428.071884
#
#      Shape_Area                                           geometry
# 0  4.791280e+09  POLYGON ((71.1172 23.21252, 71.11778 23.21247,...
# 1  6.966374e+09  POLYGON ((71.97206 23.05747, 71.97204 23.05749...
# 2  3.054307e+09  POLYGON ((73.02614 22.73478, 73.02693 22.73474...
# 3  4.002784e+09  MULTIPOLYGON (((69.33941 22.38597, 69.33976 22...
# 4  5.694271e+09  MULTIPOLYGON (((70.5365 22.40753, 70.53635 22....

# %%
df['District'] = df['District'].str.replace('>', 'A')
df['STATE'] = df['STATE'].str.replace('>', 'A')
df['District'] = df['District'].str.replace('|', 'I')
display(df.head())
# Out:
#           District    STATE REMARKS  State_LGD DISTRICT_L     Shape_Leng  \
# 0            MORBI  GUJARAT    None         24        673  539476.764723
# 1        AHMADABAD  GUJARAT    None         24        438  857254.094647
# 2            ANAND  GUJARAT    None         24        440  393046.690523
# 3  DEVBHUMI DWARKA  GUJARAT    None         24        674  661732.986530
# 4         JAMNAGAR  GUJARAT    None         24        447  737428.071884
#
#      Shape_Area                                           geometry
# 0  4.791280e+09  POLYGON ((71.1172 23.21252, 71.11778 23.21247,...
# 1  6.966374e+09  POLYGON ((71.97206 23.05747, 71.97204 23.05749...
# 2  3.054307e+09  POLYGON ((73.02614 22.73478, 73.02693 22.73474...
# 3  4.002784e+09  MULTIPOLYGON (((69.33941 22.38597, 69.33976 22...
# 4  5.694271e+09  MULTIPOLYGON (((70.5365 22.40753, 70.53635 22....

# %%
##print all the district name where state is uttar pradesh
df[df['STATE']=='UTTAR PRADESH']['District'].values
# Out:
# array(['AGRA', 'ALIGARH', 'AMBEDKARNAGAR', 'AMETHI', 'AMROHA', 'AURAIYA',
#        'AZAMGARH', 'BUDAUN', 'BAGHPAT', 'BAHRAICH', 'BALLIA', 'BALRAMPUR',
#        'BANDA', 'BARABANKI', 'BAREILLY', 'BASTI', 'BHADOHI', 'BIJNOR',
#        'BULANDSHAHR', 'CHANDAULI', 'CHITRAKOOT', 'DEORIA', 'AYODHYA',
#        'ETAH', 'ETAWAH', 'FARRUKHABAD', 'FATEHPUR', 'FIROZABAD',
#        'GAUTAMBUDHNAGAR', 'GAZIPUR', 'GHAZIABAD', 'GONDA', 'GORAKHPUR',
#        'HAMIRPUR', 'HAPUR', 'HARDOI', 'HATHRAS', 'JALAUN', 'JAUNPUR',
#        'JHANSI', 'KANNAUJ', 'KANPUR', 'KANPUR DEHAT', 'KASGANJ',
#        'KAUSHAMBI', 'KHERI', 'KUSHINAGAR', 'LALITPUR', 'LUCKNOW',
#        'MAHOBA', 'MAINPURI', 'MATHURA', 'MAU', 'MEERUT', 'MIRZAPUR',
#        'MORADABAD', 'MUZAFFARNAGAR', 'PILIBHIT', 'PRATAPGARH',
#        'RAIBEARELI', 'RAMPUR', 'SAHARANPUR', 'SAMBHAL', 'SANTKABIRNAGAR',
#        'SHAHJAHANPUR', 'SHAMLI', 'SHRAWASTI', 'SIDDHARTHNAGAR', 'SITAPUR',
#        'SONBHADRA', 'SULTANPUR', 'UNNAO', 'VARANASI', 'PRAYAGRAJ',
#        'MAHARAJGANJ'], dtype=object)

# %%
## print all up districts which comes underncr region
ncr_districts = ['GHAZIABAD',
                 'GAUTAMBUDHNAGAR',
                   'MEERUT', 'BULANDSHAHR', 'HAPUR',
                     'BAGHPAT', 'MUZAFFARNAGAR', 'SHAMLI','BHIWANI', 'FARIDABAD', 
                     'GURUGRAM', 'MAHENDRAGARH', 'REWARI', 'PALWAL', 'JHAJJAR', 'MEWAT', 'SONIPAT', 'PANIPAT',
                       'ROHTAK', 'JIND', 'KARNAL',
                       'CHARKHI DADRI',
                       'CENTRAL',  'NEW DELHI','NORTH EAST',
                        'NORTH WEST', 'SHAHADRA', 
                        'SOUTH EAST','ALWAR','BHARATPUR']
ncr_df = df[df['District'].isin(ncr_districts)]
display(len(ncr_df))
# Out:
# 30

# %%
# ncr_df

# %%
# ncr_df.columns

# %%
# fig, ax = plt.subplots(dpi=300, figsize=(6, 5))
# ncr_df.plot(ax=ax, color="none", edgecolor="black", linewidth=0.5)

# %%
#save the ncr region shapefile
# ncr_df.to_file("ncr_region.shp")

# %%
# india_shape = gpd.read_file("../raw_shapefiles/India-State-and-Country-Shapefile-Updated-Jan-2020/India_State_Boundary.shp").to_crs("EPSG:4326")

kiln_locations = []
for state in ["uttar_pradesh", "bihar", "west_bengal", "haryana", "punjab"]:
    kiln_locations.append(gpd.read_file(f"/home/patel_zeel/kiln_compass_24/final_data/labels/{state}.geojson").to_crs("EPSG:4326"))
all_kilns_gdf = pd.concat(kiln_locations, ignore_index=True)
len(all_kilns_gdf)
# Out:
# 30638

# %%
#make gpd polygon geomety
import geopandas as gpd
from shapely.geometry import Polygon

# Define coordinates for the polygon
coords = [
    (87.956564, 22.118702),
    (87.984030, 22.118702),
    (87.984030, 22.093255),
    (87.956564, 22.093255),
    (87.956564, 22.118702)  # Closing the polygon
]

# Create the Polygon geometry
poly = Polygon(coords)

# Create a GeoDataFrame
gdf = gpd.GeoDataFrame({"geometry": [poly]}, crs="EPSG:4326")

# Display the GeoDataFrame
print(gdf)
# Out:
#                                             geometry
# 0  POLYGON ((87.95656 22.1187, 87.98403 22.1187, ...

# %%
all_kilns_gdf.head()
all_kilns_gdf = all_kilns_gdf.to_crs("EPSG:3857")
all_kilns_gdf.head()
# Out:
#   class_name  confidence    max_lon    min_lon    max_lat    min_lat  \
# 0      CFCBK    0.954724  83.316463  83.315927  26.482172  26.481690
# 1     Zigzag         NaN  80.828830  80.827608  26.611726  26.610867
# 2       FCBK         NaN  80.980050  80.978762  26.612827  26.611865
# 3     Zigzag         NaN  80.980816  80.980096  26.614673  26.613643
# 4       FCBK         NaN  81.047645  81.046868  26.608603  26.607481
#
#    center_lat  center_lon  width_of_box  height_of_box  ...  geo_box   x   y  \
# 0   26.481931   83.316195     53.359356      53.363670  ...     None NaN NaN
# 1   26.611297   80.828219    121.703260      95.174997  ...     None NaN NaN
# 2   26.612346   80.979406    128.275203     106.587149  ...     None NaN NaN
# 3   26.614158   80.980456     71.705484     114.121405  ...     None NaN NaN
# 4   26.608042   81.047257     77.386253     124.314666  ...     None NaN NaN
#
#   yolo_label style                                           geometry epsg  \
# 0       None  None  POLYGON ((9274686.235 3058864.165, 9274746.013...  NaN
# 1       None  None  POLYGON ((8997800.152 3074938.277, 8997824.197...  NaN
# 2       None  None  POLYGON ((9014657.93 3075111.844, 9014545.498 ...  NaN
# 3       None  None  POLYGON ((9014718.377 3075283.918, 9014743.201...  NaN
# 4       None  None  POLYGON ((9022141.049 3074516.697, 9022182.571...  NaN
#
#    image_center_x image_center_y resolution
# 0             NaN            NaN        NaN
# 1             NaN            NaN        NaN
# 2             NaN            NaN        NaN
# 3             NaN            NaN        NaN
# 4             NaN            NaN        NaN
#
# [5 rows x 36 columns]

# %%
import geopandas as gpd
from shapely.geometry import Point, Polygon

# Define polygon geometry
coords = [
    (87.956564, 22.118702),
    (87.984030, 22.118702),
    (87.984030, 22.093255),
    (87.956564, 22.093255),
    (87.956564, 22.118702)  # Closing the polygon
]

polygon = Polygon(coords)
gdf = gpd.GeoDataFrame({"geometry": [polygon]}, crs="EPSG:4326")

# Convert kiln coordinates to GeoDataFrame
center_coords = all_kilns_gdf[['center_lat', 'center_lon']].copy()
center_coords = gpd.GeoDataFrame(
    center_coords,
    geometry=gpd.points_from_xy(center_coords.center_lon, center_coords.center_lat),
    crs="EPSG:4326"
)

# Ensure both have the same CRS
print("Kiln CRS:", center_coords.crs)
print("Polygon CRS:", gdf.crs)

# Perform spatial join to find kilns inside the polygon
kilns_in_gpd = gpd.sjoin(center_coords, gdf, how='inner', predicate='within')

# Display the count of kilns inside the polygon
print("Number of kilns inside polygon:", kilns_in_gpd.shape[0])
# Out:
# Kiln CRS: EPSG:4326
# Polygon CRS: EPSG:4326
# Number of kilns inside polygon: 16

# %%
## select the kilns which are in under gpd polygon
center_coords=all_kilns_gdf[['center_lat', 'center_lon']]
center_coords = gpd.GeoDataFrame(center_coords, geometry=gpd.points_from_xy(center_coords.center_lon, center_coords.center_lat))
print(center_coords.crs)
#Select that kilns which are in the gpd polygon using sjoin
kilns_in_gpd = gpd.sjoin(center_coords, gdf, how='inner')
kilns_in_gpd.count()
# Out:
# None
# /tmp/ipykernel_3925770/1558866656.py:6: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   kilns_in_gpd = gpd.sjoin(center_coords, gdf, how='inner')
# center_lat     16
# center_lon     16
# geometry       16
# index_right    16
# dtype: int64

# %%
kiln_locations_bihar = []
for state in ["bihar"]:
    kiln_locations_bihar.append(gpd.read_file(f"/home/patel_zeel/kiln_compass_24/final_data/labels/{state}.geojson").to_crs("EPSG:4326"))
all_kilns_gdf_bihar = pd.concat(kiln_locations_bihar, ignore_index=True)
len(all_kilns_gdf_bihar)
# Out:
# 6048

# %%
all_bk=all_kilns_gdf_bihar[['center_lat','center_lon']]
all_bk.head(2)
all_bk.tail(2)
#save as kml
all_bk.to_csv("../raw_data/raw_shapefile/all_bk_bihar.csv",index=False)

all_bk = gpd.GeoDataFrame(all_bk, geometry=gpd.points_from_xy(all_bk.center_lon, all_bk.center_lat))
all_bk.crs = "EPSG:4326"
all_bk.head(2)
all_bk.to_file("../raw_data/raw_shapefile/all_bk_bihar.kml", driver='KML')

# %%
all_kilns_gdf.head(2)
# Out:
#   class_name  confidence    max_lon    min_lon    max_lat    min_lat  \
# 0      CFCBK    0.954724  83.316463  83.315927  26.482172  26.481690
# 1     Zigzag         NaN  80.828830  80.827608  26.611726  26.610867
#
#    center_lat  center_lon  width_of_box  height_of_box  ...  geo_box   x   y  \
# 0   26.481931   83.316195     53.359356      53.363670  ...     None NaN NaN
# 1   26.611297   80.828219    121.703260      95.174997  ...     None NaN NaN
#
#   yolo_label style                                           geometry epsg  \
# 0       None  None  POLYGON ((83.31592 26.48169, 83.31646 26.48169...  NaN
# 1       None  None  POLYGON ((80.82861 26.61087, 80.82883 26.6114,...  NaN
#
#    image_center_x image_center_y resolution
# 0             NaN            NaN        NaN
# 1             NaN            NaN        NaN
#
# [2 rows x 36 columns]

# %%
all_bk=all_kilns_gdf[['center_lat','center_lon']]
all_bk.head(2)
all_bk.tail(2)
#save as kml
all_bk.to_csv("../raw_data/raw_shapefile/all_bk.csv",index=False)

all_bk = gpd.GeoDataFrame(all_bk, geometry=gpd.points_from_xy(all_bk.center_lon, all_bk.center_lat))
all_bk.crs = "EPSG:4326"
all_bk.head(2)
all_bk.to_file("../raw_data/raw_shapefile/all_bk.kml", driver='KML')

# %%
all_kilns_gdf.columns
# Out:
# Index(['class_name', 'confidence', 'max_lon', 'min_lon', 'max_lat', 'min_lat',
#        'center_lat', 'center_lon', 'width_of_box', 'height_of_box',
#        'length_of_object', 'width_of_object', 'area', 'id', 'source',
#        'task_name', 'type', 'label_index', 'Name', 'Description',
#        'image_width', 'image_height', 'image_center_lat', 'image_center_lon',
#        'zoom', 'view_index', 'geo_box', 'x', 'y', 'yolo_label', 'style',
#        'geometry', 'epsg', 'image_center_x', 'image_center_y', 'resolution'],
#       dtype='object')

# %%
selected_columns = ['class_name', 'max_lon', 'min_lon', 'max_lat', 'min_lat',
                    'center_lat', 'center_lon', 'length_of_object', 'width_of_object', 'area','geometry']

# Create a new GeoDataFrame with the selected columns
new_gdf = all_kilns_gdf[selected_columns]

# Display the new GeoDataFrame
display(new_gdf.head())
# Out:
#   class_name    max_lon    min_lon    max_lat    min_lat  center_lat  \
# 0      CFCBK  83.316463  83.315927  26.482172  26.481690   26.481931
# 1     Zigzag  80.828830  80.827608  26.611726  26.610867   26.611297
# 2       FCBK  80.980050  80.978762  26.612827  26.611865   26.612346
# 3     Zigzag  80.980816  80.980096  26.614673  26.613643   26.614158
# 4       FCBK  81.047645  81.046868  26.608603  26.607481   26.608042
#
#    center_lon  length_of_object  width_of_object         area  \
# 0   83.316195         53.192355        53.186131  2829.095571
# 1   80.828219        106.428241        63.059479  6711.309411
# 2   80.979406        118.536094        51.881044  6149.776377
# 3   80.980456        105.949479        50.603529  5361.417593
# 4   81.047257        116.964595        42.411568  4960.651840
#
#                                             geometry
# 0  POLYGON ((83.31592 26.48169, 83.31646 26.48169...
# 1  POLYGON ((80.82861 26.61087, 80.82883 26.6114,...
# 2  POLYGON ((80.98005 26.61226, 80.97904 26.61283...
# 3  POLYGON ((80.98059 26.61364, 80.98082 26.61458...
# 4  POLYGON ((81.04727 26.60748, 81.04764 26.60848...

# %%
kiln_locations_2 = []
for state in ["alwar"]:
    kiln_locations_2.append(gpd.read_file(f"../hand_validation_annotated/{state}/v1_potential_kiln_0_108.geojson").to_crs("EPSG:4326"))


kiln_locations    
all_kilns_gdf_2 = pd.concat(kiln_locations_2, ignore_index=True)
new_gdf_2=all_kilns_gdf_2[selected_columns]
display(new_gdf_2.head())
# Out:
#   class_name    max_lon    min_lon    max_lat    min_lat  center_lat  \
# 0       FCBK  76.709489  76.708268  27.678342  27.677199   27.677771
# 1     Zigzag  76.317248  76.316083  27.881041  27.880191   27.880616
# 2       FCBK  76.867633  76.866236  27.409807  27.408873   27.409340
# 3     Zigzag  76.345456  76.344230  27.990465  27.989738   27.990102
# 4       FCBK  76.470084  76.469287  27.923740  27.922866   27.923303
#
#    center_lon  length_of_object  width_of_object         area  \
# 0   76.708878        117.591123        57.714601  6786.724753
# 1   76.316665        101.215202        53.522593  5417.300068
# 2   76.866934        126.638111        54.939837  6957.477131
# 3   76.344843        110.297146        54.543065  6015.944406
# 4   76.469685         89.328078        39.222817  3503.698836
#
#                                             geometry
# 0  POLYGON ((76.7087 27.67722, 76.70947 27.67803,...
# 1  POLYGON ((76.31702 27.8802, 76.31727 27.88063,...
# 2  POLYGON ((76.86738 27.40888, 76.86762 27.40933...
# 3  POLYGON ((76.34531 27.98974, 76.34545 27.99022...
# 4  POLYGON ((76.4696 27.92287, 76.47005 27.92358,...

# %%
kiln_locations_3 = []
for state in ["bharatpur"]:
    kiln_locations_3.append(gpd.read_file(f"../hand_validation_annotated/{state}/v1_potential_kiln_0_99.geojson").to_crs("EPSG:4326"))


kiln_locations_3
all_kilns_gdf_3 = pd.concat(kiln_locations_3, ignore_index=True)
new_gdf_3= all_kilns_gdf_3[selected_columns]

# %%
new_gdf_3.head()
# Out:
#   class_name    max_lon    min_lon    max_lat    min_lat  center_lat  \
# 0     Zigzag  77.122994  77.122013  27.227222  27.225987   27.226605
# 1     Zigzag  77.243371  77.242168  27.144951  27.144103   27.144527
# 2     Zigzag  77.210987  77.209591  27.127441  27.126299   27.126870
# 3     Zigzag  77.205127  77.204291  27.293237  27.292495   27.292866
# 4     Zigzag  77.089212  77.088226  27.484057  27.483009   27.483533
#
#    center_lon  length_of_object  width_of_object         area  \
# 0   77.122503        126.014984        53.944823  6797.855969
# 1   77.242770        104.273153        60.918771  6352.192398
# 2   77.210289        125.446312        63.481964  7963.578329
# 3   77.204709         78.338812        77.809881  6095.533660
# 4   77.088719        102.511612        54.948597  5632.869252
#
#                                             geometry
# 0  POLYGON ((77.1225 27.22599, 77.12297 27.22705,...
# 1  POLYGON ((77.24316 27.1441, 77.24338 27.14462,...
# 2  POLYGON ((77.20999 27.1263, 77.211 27.12698, 7...
# 3  POLYGON ((77.2049 27.29255, 77.20499 27.29287,...
# 4  POLYGON ((77.08866 27.48306, 77.08907 27.48321...

# %%
# Concatenate the GeoDataFrames
combined_gdf = gpd.GeoDataFrame(pd.concat([new_gdf, new_gdf_2, new_gdf_3], ignore_index=True))

# Display the combined GeoDataFrame
display(combined_gdf.head(2))
print(len(combined_gdf))
# Out:
#   class_name    max_lon    min_lon    max_lat    min_lat  center_lat  \
# 0      CFCBK  83.316463  83.315927  26.482172  26.481690   26.481931
# 1     Zigzag  80.828830  80.827608  26.611726  26.610867   26.611297
#
#    center_lon  length_of_object  width_of_object         area  \
# 0   83.316195         53.192355        53.186131  2829.095571
# 1   80.828219        106.428241        63.059479  6711.309411
#
#                                             geometry
# 0  POLYGON ((83.31592 26.48169, 83.31646 26.48169...
# 1  POLYGON ((80.82861 26.61087, 80.82883 26.6114,...
# 30808

# %%
ncr_kilns_gdf = gpd.sjoin(combined_gdf, ncr_df, how="inner")
ncr_kilns_gdf.head(10)
# Out:
#     class_name    max_lon    min_lon    max_lat    min_lat  center_lat  \
# 392     Zigzag  77.713012  77.711831  28.632415  28.631113   28.631764
# 393     Zigzag  77.269406  77.268001  28.896197  28.895197   28.895697
# 411     Zigzag  77.408647  77.407173  28.996799  28.995468   28.996134
# 416     Zigzag  77.890942  77.889639  29.524163  29.523163   29.523663
# 442       FCBK  78.075846  78.074732  28.776447  28.775610   28.776028
# 443       FCBK  78.075376  78.074204  28.778714  28.777537   28.778125
# 445     Zigzag  77.641867  77.640718  29.503233  29.502134   29.502683
# 446     Zigzag  77.641320  77.639864  29.499025  29.498000   29.498513
# 447     Zigzag  77.644049  77.643060  29.495896  29.494805   29.495351
# 479     Zigzag  77.346402  77.345004  28.761999  28.760867   28.761433
#
#      center_lon  length_of_object  width_of_object         area  \
# 392   77.712422        136.734492        52.888869  7231.732630
# 393   77.268704        121.272891        63.209074  7665.547148
# 411   77.407910        132.425504        73.718450  9762.202867
# 416   77.890290        115.487683        54.839052  6333.234992
# 442   78.075289         98.555226        47.503574  4681.725466
# 443   78.074790        121.252473        54.594423  6619.708759
# 445   77.641292        111.612956        54.789611  6115.230461
# 446   77.640592        128.764487        58.539958  7537.867715
# 447   77.643554        105.962349        62.080871  6578.234906
# 479   77.345703        112.680722        76.696088  8642.170581
#
#                                               geometry  index_right  \
# 392  POLYGON ((77.7123 28.63111, 77.71301 28.63217,...          160
# 393  POLYGON ((77.26911 28.8952, 77.26941 28.8957, ...           34
# 411  POLYGON ((77.40808 28.99547, 77.40865 28.99591...           34
# 416  POLYGON ((77.89062 29.52316, 77.89094 29.52357...          256
# 442  POLYGON ((78.07558 28.77561, 78.07585 28.77597...          160
# 443  POLYGON ((78.0742 28.77782, 78.07466 28.77754,...          160
# 445  POLYGON ((77.64117 29.50213, 77.64187 29.50294...          256
# 446  POLYGON ((77.64102 29.498, 77.64132 29.49846, ...          256
# 447  POLYGON ((77.64366 29.4948, 77.64405 29.4957, ...          256
# 479  POLYGON ((77.34597 28.76087, 77.3464 28.76145,...          146
#
#           District          STATE REMARKS  State_LGD DISTRICT_L  \
# 392          HAPUR  UTTAR PRADESH    None          9        661
# 393        BAGHPAT  UTTAR PRADESH    None          9        124
# 411        BAGHPAT  UTTAR PRADESH    None          9        124
# 416  MUZAFFARNAGAR  UTTAR PRADESH    None          9        172
# 442          HAPUR  UTTAR PRADESH    None          9        661
# 443          HAPUR  UTTAR PRADESH    None          9        661
# 445  MUZAFFARNAGAR  UTTAR PRADESH    None          9        172
# 446  MUZAFFARNAGAR  UTTAR PRADESH    None          9        172
# 447  MUZAFFARNAGAR  UTTAR PRADESH    None          9        172
# 479      GHAZIABAD  UTTAR PRADESH    None          9        145
#
#         Shape_Leng    Shape_Area
# 392  246171.836916  1.081375e+09
# 393  218392.986381  1.281800e+09
# 411  218392.986381  1.281800e+09
# 416  343519.238829  2.657073e+09
# 442  246171.836916  1.081375e+09
# 443  246171.836916  1.081375e+09
# 445  343519.238829  2.657073e+09
# 446  343519.238829  2.657073e+09
# 447  343519.238829  2.657073e+09
# 479  217418.360053  8.824112e+08

# %%
len(ncr_kilns_gdf)
# Out:
# 3581

# %%
ncr_kilns_gdf.head(2)
# Out:
#     class_name    max_lon    min_lon    max_lat    min_lat  center_lat  \
# 392     Zigzag  77.713012  77.711831  28.632415  28.631113   28.631764
# 393     Zigzag  77.269406  77.268001  28.896197  28.895197   28.895697
#
#      center_lon  length_of_object  width_of_object         area  \
# 392   77.712422        136.734492        52.888869  7231.732630
# 393   77.268704        121.272891        63.209074  7665.547148
#
#                                               geometry  index_right District  \
# 392  POLYGON ((77.7123 28.63111, 77.71301 28.63217,...          160    HAPUR
# 393  POLYGON ((77.26911 28.8952, 77.26941 28.8957, ...           34  BAGHPAT
#
#              STATE REMARKS  State_LGD DISTRICT_L     Shape_Leng    Shape_Area
# 392  UTTAR PRADESH    None          9        661  246171.836916  1.081375e+09
# 393  UTTAR PRADESH    None          9        124  218392.986381  1.281800e+09

# %%
#give me district wise count of kilns in ncr region
ncr_kilns_gdf['District'].value_counts()
# Out:
# District
# BAGHPAT            434
# BULANDSHAHR        379
# MUZAFFARNAGAR      342
# JHAJJAR            288
# GHAZIABAD          249
# SONIPAT            206
# MEERUT             202
# SHAMLI             157
# HAPUR              128
# PALWAL             123
# JIND               118
# BHIWANI            109
# ROHTAK              95
# FARIDABAD           95
# GAUTAMBUDHNAGAR     92
# BHARATPUR           90
# KARNAL              85
# ALWAR               80
# MEWAT               77
# PANIPAT             74
# REWARI              70
# MAHENDRAGARH        59
# CHARKHI DADRI       22
# GURUGRAM             5
# NORTH WEST           2
# Name: count, dtype: int64

# %%
#give me district wise class wise no of kilns in ncr region
ncr_kilns_gdf.groupby(['District', 'class_name']).size()
# Out:
# District         class_name
# ALWAR            FCBK           14
#                  Zigzag         66
# BAGHPAT          FCBK           20
#                  Zigzag        414
# BHARATPUR        FCBK           12
#                  Zigzag         78
# BHIWANI          FCBK            1
#                  Zigzag        108
# BULANDSHAHR      CFCBK          11
#                  FCBK           85
#                  Zigzag        283
# CHARKHI DADRI    FCBK            2
#                  Zigzag         20
# FARIDABAD        FCBK            4
#                  Zigzag         91
# GAUTAMBUDHNAGAR  CFCBK           7
#                  FCBK           10
#                  Zigzag         75
# GHAZIABAD        FCBK           25
#                  Zigzag        224
# GURUGRAM         FCBK            2
#                  Zigzag          3
# HAPUR            CFCBK           1
#                  FCBK           26
#                  Zigzag        101
# JHAJJAR          FCBK            7
#                  Zigzag        281
# JIND             FCBK            9
#                  Zigzag        109
# KARNAL           FCBK            5
#                  Zigzag         80
# MAHENDRAGARH     FCBK            8
#                  Zigzag         51
# MEERUT           CFCBK           3
#                  FCBK           24
#                  Zigzag        175
# MEWAT            FCBK            5
#                  Zigzag         72
# MUZAFFARNAGAR    FCBK            9
#                  Zigzag        333
# NORTH WEST       Zigzag          2
# PALWAL           FCBK            7
#                  Zigzag        116
# PANIPAT          FCBK            1
#                  Zigzag         73
# REWARI           FCBK            2
#                  Zigzag         68
# ROHTAK           FCBK            7
#                  Zigzag         88
# SHAMLI           FCBK            8
#                  Zigzag        149
# SONIPAT          FCBK           11
#                  Zigzag        195
# dtype: int64

# %%
# make a csv file of the above data where columns are district name, class name and count of kilns
ncr_kilns_gdf.groupby(['District', 'class_name']).size().reset_index(name='count').to_csv('../result_csv/ncr_kilns_count.csv', index=False)

# %%
# df[['CFCBK','FCBK','Zigzag']] = df[['CFCBK','FCBK','Zigzag']].astype(int)
df.to_csv('../result_csv/ncr_kilns_count.csv', index=False)
df.head()
# Out:
#           District    STATE REMARKS  State_LGD DISTRICT_L     Shape_Leng  \
# 0            MORBI  GUJARAT    None         24        673  539476.764723
# 1        AHMADABAD  GUJARAT    None         24        438  857254.094647
# 2            ANAND  GUJARAT    None         24        440  393046.690523
# 3  DEVBHUMI DWARKA  GUJARAT    None         24        674  661732.986530
# 4         JAMNAGAR  GUJARAT    None         24        447  737428.071884
#
#      Shape_Area                                           geometry
# 0  4.791280e+09  POLYGON ((71.1172 23.21252, 71.11778 23.21247,...
# 1  6.966374e+09  POLYGON ((71.97206 23.05747, 71.97204 23.05749...
# 2  3.054307e+09  POLYGON ((73.02614 22.73478, 73.02693 22.73474...
# 3  4.002784e+09  MULTIPOLYGON (((69.33941 22.38597, 69.33976 22...
# 4  5.694271e+09  MULTIPOLYGON (((70.5365 22.40753, 70.53635 22....

# %%
#make the  all value in integer
df['District']
# Out:
# 0               ALWAR
# 1             BAGHPAT
# 2           BHARATPUR
# 3             BHIWANI
# 4         BULANDSHAHR
# 5       CHARKHI DADRI
# 6           FARIDABAD
# 7     GAUTAMBUDHNAGAR
# 8           GHAZIABAD
# 9            GURUGRAM
# 10              HAPUR
# 11            JHAJJAR
# 12               JIND
# 13             KARNAL
# 14       MAHENDRAGARH
# 15             MEERUT
# 16              MEWAT
# 17      MUZAFFARNAGAR
# 18         NORTH WEST
# 19             PALWAL
# 20            PANIPAT
# 21             REWARI
# 22             ROHTAK
# 23             SHAMLI
# 24            SONIPAT
# Name: District, dtype: object

# %%
##Make FCBK and Zigzag is A different COLUMN
# df = df.pivot(index='District', columns='class_name', values='count').reset_index()
df.head()
df.fillna(0, inplace=True)
# display(df.head())
#change the column name class_name to index
df.rename(columns={'class_name':'index'}, inplace=True)
df.to_csv('../result_csv/ncr_kilns_count.csv', index=False)

# %%
display(ncr_kilns_gdf[['geometry']].iloc[0])
# Out:
# geometry    POLYGON ((77.7123 28.63111, 77.71301 28.63217,...
# Name: 392, dtype: geometry

# %%
display(ncr_kilns_gdf[['geometry']].iloc[0])
# Out:
# geometry    POLYGON ((77.7123 28.63111, 77.71301 28.63217,...
# Name: 392, dtype: geometry

# %%
selected_columns = ['class_name', 'max_lon', 'min_lon', 'max_lat', 'min_lat',
                    'center_lat', 'center_lon', 'length_of_object', 'width_of_object', 'area','geometry']
final_ncr_brick_kilns_gdf=ncr_kilns_gdf[selected_columns]
final_ncr_brick_kilns_gdf.head()
# Out:
#     class_name    max_lon    min_lon    max_lat    min_lat  center_lat  \
# 392     Zigzag  77.713012  77.711831  28.632415  28.631113   28.631764
# 393     Zigzag  77.269406  77.268001  28.896197  28.895197   28.895697
# 411     Zigzag  77.408647  77.407173  28.996799  28.995468   28.996134
# 416     Zigzag  77.890942  77.889639  29.524163  29.523163   29.523663
# 442       FCBK  78.075846  78.074732  28.776447  28.775610   28.776028
#
#      center_lon  length_of_object  width_of_object         area  \
# 392   77.712422        136.734492        52.888869  7231.732630
# 393   77.268704        121.272891        63.209074  7665.547148
# 411   77.407910        132.425504        73.718450  9762.202867
# 416   77.890290        115.487683        54.839052  6333.234992
# 442   78.075289         98.555226        47.503574  4681.725466
#
#                                               geometry
# 392  POLYGON ((77.7123 28.63111, 77.71301 28.63217,...
# 393  POLYGON ((77.26911 28.8952, 77.26941 28.8957, ...
# 411  POLYGON ((77.40808 28.99547, 77.40865 28.99591...
# 416  POLYGON ((77.89062 29.52316, 77.89094 29.52357...
# 442  POLYGON ((78.07558 28.77561, 78.07585 28.77597...

# %%
# Save the final GeoDataFrame to a shapefile in jeojson format
final_ncr_brick_kilns_gdf.to_file("../regions/shapes/ncr_brick_kilns.geojson", driver="GeoJSON")

# %%
delhi_ncr_kilns_gdf = ncr_kilns_gdf[selected_columns]
print(len(delhi_ncr_kilns_gdf))
display(delhi_ncr_kilns_gdf.head(2))
# Out:
# 3581
#     class_name    max_lon    min_lon    max_lat    min_lat  center_lat  \
# 392     Zigzag  77.713012  77.711831  28.632415  28.631113   28.631764
# 393     Zigzag  77.269406  77.268001  28.896197  28.895197   28.895697
#
#      center_lon  length_of_object  width_of_object         area  \
# 392   77.712422        136.734492        52.888869  7231.732630
# 393   77.268704        121.272891        63.209074  7665.547148
#
#                                               geometry
# 392  POLYGON ((77.7123 28.63111, 77.71301 28.63217,...
# 393  POLYGON ((77.26911 28.8952, 77.26941 28.8957, ...

# %%
# Align CRS if different
if delhi_ncr_kilns_gdf.crs != ncr_df.crs:
    delhi_ncr_kilns_gdf = delhi_ncr_kilns_gdf.to_crs(ncr_df.crs)

# %%
# Create a new GeoDataFrame for combined data
combined_gdf = gpd.GeoDataFrame(pd.concat([ncr_df, delhi_ncr_kilns_gdf], ignore_index=True))

# %%
combined_gdf.head(2)
len(combined_gdf)
# Out:
# 3611

# %%
# combined_gdf

# %%
combined_gdf.to_file("delhi_ncr_kilns_combined.kml", driver="KML")
print("Combined GeoDataFrame saved as KML.")
# Out:
# Combined GeoDataFrame saved as KML.
# /opt/anaconda3/envs/rishabh_sat/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 'Zigzag' of field delhi_ncr_kilns_combined.Shape_Leng parsed incompletely to real 0.
#   ogr_write(
# /opt/anaconda3/envs/rishabh_sat/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 'FCBK' of field delhi_ncr_kilns_combined.Shape_Leng parsed incompletely to real 0.
#   ogr_write(
# /opt/anaconda3/envs/rishabh_sat/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 'CFCBK' of field delhi_ncr_kilns_combined.Shape_Leng parsed incompletely to real 0.
#   ogr_write(

# %%
combined_gdf.to_file("../hand_validation_annotated/delhi_ncr_kilns_combined.geojson", driver="GeoJSON")
print("Combined GeoDataFrame saved as GeoJSON.")
combined_gdf.to_file("../hand_validation_annotated/delhi_ncr_kilns_combined.shp",driver="ESRI Shapefile")
print("Combined GeoDataFrame saved as Shapefile.")
# Out:
# Combined GeoDataFrame saved as GeoJSON.
# Combined GeoDataFrame saved as Shapefile.
# /tmp/ipykernel_2568358/2000974214.py:3: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   combined_gdf.to_file("../hand_validation_annotated/delhi_ncr_kilns_combined.shp",driver="ESRI Shapefile")
# /opt/anaconda3/envs/rishabh_sat/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Normalized/laundered field name: 'length_of_object' to 'length_of_'
#   ogr_write(
# /opt/anaconda3/envs/rishabh_sat/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Normalized/laundered field name: 'width_of_object' to 'width_of_o'
#   ogr_write(
# /opt/anaconda3/envs/rishabh_sat/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 8091212384.84000015 of field Shape_Area of feature 0 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /opt/anaconda3/envs/rishabh_sat/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 1281800382.94000006 of field Shape_Area of feature 1 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /opt/anaconda3/envs/rishabh_sat/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 4881165658.53999996 of field Shape_Area of feature 2 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /opt/anaconda3/envs/rishabh_sat/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 3402373200.40999985 of field Shape_Area of feature 3 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /opt/anaconda3/envs/rishabh_sat/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 103186016.093999997 of field Shape_Area of feature 4 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /opt/anaconda3/envs/rishabh_sat/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 1367580032.3900001 of field Shape_Area of feature 5 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /opt/anaconda3/envs/rishabh_sat/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 882411235.643000007 of field Shape_Area of feature 6 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /opt/anaconda3/envs/rishabh_sat/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 1081374944.17000008 of field Shape_Area of feature 7 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /opt/anaconda3/envs/rishabh_sat/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 2512807895.46999979 of field Shape_Area of feature 8 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /opt/anaconda3/envs/rishabh_sat/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 2657072857.88999987 of field Shape_Area of feature 9 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /opt/anaconda3/envs/rishabh_sat/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 151623804.294999987 of field Shape_Area of feature 10 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /opt/anaconda3/envs/rishabh_sat/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 149032948.340000004 of field Shape_Area of feature 12 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /opt/anaconda3/envs/rishabh_sat/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 1226415733.76999998 of field Shape_Area of feature 14 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /opt/anaconda3/envs/rishabh_sat/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 3186628724.21000004 of field Shape_Area of feature 16 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /opt/anaconda3/envs/rishabh_sat/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 718856360.797000051 of field Shape_Area of feature 17 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /opt/anaconda3/envs/rishabh_sat/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 1209068040.6099999 of field Shape_Area of feature 18 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /opt/anaconda3/envs/rishabh_sat/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 1798823691.95000005 of field Shape_Area of feature 19 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /opt/anaconda3/envs/rishabh_sat/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 2649068440.13999987 of field Shape_Area of feature 20 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /opt/anaconda3/envs/rishabh_sat/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 2405776731.96999979 of field Shape_Area of feature 21 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /opt/anaconda3/envs/rishabh_sat/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 1869906630.48000002 of field Shape_Area of feature 22 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /opt/anaconda3/envs/rishabh_sat/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 1463782591.41000009 of field Shape_Area of feature 23 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /opt/anaconda3/envs/rishabh_sat/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 1313937684.51999998 of field Shape_Area of feature 24 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /opt/anaconda3/envs/rishabh_sat/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 1263800771.46000004 of field Shape_Area of feature 25 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /opt/anaconda3/envs/rishabh_sat/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 1501531415.54999995 of field Shape_Area of feature 26 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /opt/anaconda3/envs/rishabh_sat/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 1616224665.17000008 of field Shape_Area of feature 27 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /opt/anaconda3/envs/rishabh_sat/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 2112606012.03999996 of field Shape_Area of feature 28 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /opt/anaconda3/envs/rishabh_sat/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 1338808894.22000003 of field Shape_Area of feature 29 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(

# %%
delhi_ncr_kilns_gdf.to_file("../hand_validation_annotated/ncr_kilns.geojson", driver="GeoJSON")
delhi_ncr_kilns_gdf.to_file("../hand_validation_annotated/ncr_kilns.shp", driver="ESRI Shapefile")
delhi_ncr_kilns_gdf.to_file("../hand_validation_annotated/ncr_kilns.kml", driver="KML")
# Out:
# /tmp/ipykernel_2568358/4225450842.py:2: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   delhi_ncr_kilns_gdf.to_file("../hand_validation_annotated/ncr_kilns.shp", driver="ESRI Shapefile")
# /opt/anaconda3/envs/rishabh_sat/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Normalized/laundered field name: 'length_of_object' to 'length_of_'
#   ogr_write(
# /opt/anaconda3/envs/rishabh_sat/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Normalized/laundered field name: 'width_of_object' to 'width_of_o'
#   ogr_write(

# %%
ncr_kilns_gdf = gpd.sjoin(all_kilns_gdf, ncr_df, how="inner")
ncr_kilns_gdf.head()
ncr_kilns_gdf_2 = gpd.sjoin(all_kilns_gdf_2, ncr_df, how="inner")
ncr_kilns_gdf_3 = gpd.sjoin(all_kilns_gdf_3, ncr_df, how="inner")

# %%
# latexify(5, 2, font_size=10)

kiln_tech = "CFCBK"
kiln_tech = "FCBK"
kiln_tech = "Zigzag"

fig, ax = plt.subplots(dpi=300, figsize=(10, 10))
ncr_df.plot(ax=ax, color="none", edgecolor="black", linewidth=0.5)

# scatter plot of the kiln locations
CFCBK_kilns = all_kilns_gdf[all_kilns_gdf["class_name"] == "CFCBK"]
FCBK_kilns = all_kilns_gdf[all_kilns_gdf["class_name"] == "FCBK"]
Zigzag_kilns = all_kilns_gdf[all_kilns_gdf["class_name"] == "Zigzag"]
CFCBK_kilns_2 = all_kilns_gdf_2[all_kilns_gdf_2["class_name"] == "CFCBK"]
FCBK_kilns_2 = all_kilns_gdf_2[all_kilns_gdf_2["class_name"] == "FCBK"]
Zigzag_kilns_2 = all_kilns_gdf_2[all_kilns_gdf_2["class_name"] == "Zigzag"]
CFCBK_kilns_3 = all_kilns_gdf_3[all_kilns_gdf_3["class_name"] == "CFCBK"]
FCBK_kilns_3 = all_kilns_gdf_3[all_kilns_gdf_3["class_name"] == "FCBK"]
Zigzag_kilns_3 = all_kilns_gdf_3[all_kilns_gdf_3["class_name"] == "Zigzag"]


if kiln_tech == "CFCBK":
    ax.scatter(CFCBK_kilns.center_lon, CFCBK_kilns.center_lat, s=0.1, color='red')
    ax.scatter(CFCBK_kilns_2.center_lon, CFCBK_kilns_2.center_lat, s=0.1, color='red')
    ax.scatter(CFCBK_kilns_3.center_lon, CFCBK_kilns_3.center_lat, s=0.1, color='red')
elif kiln_tech == "FCBK":
    ax.scatter(FCBK_kilns.center_lon, FCBK_kilns.center_lat, s=0.1, color='orange')
    ax.scatter(FCBK_kilns_2.center_lon, FCBK_kilns_2.center_lat, s=0.1, color='orange')
    ax.scatter(FCBK_kilns_3.center_lon, FCBK_kilns_3.center_lat, s=0.1, color='orange')

elif kiln_tech == "Zigzag":
    ax.scatter(Zigzag_kilns.center_lon, Zigzag_kilns.center_lat, s=0.1, color='green')
    ax.scatter(Zigzag_kilns_2.center_lon, Zigzag_kilns_2.center_lat, s=0.1, color='green')
    ax.scatter(Zigzag_kilns_3.center_lon, Zigzag_kilns_3.center_lat, s=0.1, color='green')

ax.set_aspect("equal")
ax.set_axis_off()

# %%
import matplotlib.pyplot as plt
import geopandas as gpd

# Filter the kilns within NCR boundaries using a spatial join
# ncr_kilns_gdf = gpd.sjoin(all_kilns_gdf, ncr_df, how="inner")

kiln_tech = "CFCBK"
if kiln_tech == "CFCBK":
    filtered_kilns = ncr_kilns_gdf[ncr_kilns_gdf["class_name"] == "CFCBK"]
    filtered_kilns_2 = ncr_kilns_gdf_2[ncr_kilns_gdf_2["class_name"] == "CFCBK"]
    filtered_kilns_3 = ncr_kilns_gdf_3[ncr_kilns_gdf_3["class_name"] == "CFCBK"]
    print(len(filtered_kilns))
    print(len(filtered_kilns_2))
    print(len(filtered_kilns_3))
    total_kilns = len(filtered_kilns) + len(filtered_kilns_2) + len(filtered_kilns_3)
    
    color = 'red'
elif kiln_tech == "FCBK":
    filtered_kilns = ncr_kilns_gdf[ncr_kilns_gdf["class_name"] == "FCBK"]
    filtered_kilns_2 = ncr_kilns_gdf_2[ncr_kilns_gdf_2["class_name"] == "FCBK"]
    filtered_kilns_3 = ncr_kilns_gdf_3[ncr_kilns_gdf_3["class_name"] == "FCBK"]

    print(len(filtered_kilns))
    print(len(filtered_kilns_2))
    print(len(filtered_kilns_3))
    total_kilns = len(filtered_kilns) + len(filtered_kilns_2) + len(filtered_kilns_3)

    color = 'orange'
elif kiln_tech == "Zigzag":
    filtered_kilns = ncr_kilns_gdf[ncr_kilns_gdf["class_name"] == "Zigzag"]
    filtered_kilns_2 = ncr_kilns_gdf_2[ncr_kilns_gdf_2["class_name"] == "Zigzag"]
    filtered_kilns_3 = ncr_kilns_gdf_3[ncr_kilns_gdf_3["class_name"] == "Zigzag"]

    print(len(filtered_kilns))
    print(len(filtered_kilns_2))
    print(len(filtered_kilns_3))
    total_kilns = len(filtered_kilns) + len(filtered_kilns_2) + len(filtered_kilns_3)
    color = 'green'
else:
    raise ValueError("Invalid kiln technology specified!")

fig, ax = plt.subplots(dpi=300, figsize=(10, 10))
ncr_df.plot(ax=ax, color="none", edgecolor="black", linewidth=1)
ax.scatter(filtered_kilns.center_lon, filtered_kilns.center_lat, s=7.5, color=color)
ax.scatter(filtered_kilns_2.center_lon, filtered_kilns_2.center_lat, s=7.5, color=color)
ax.scatter(filtered_kilns_3.center_lon, filtered_kilns_3.center_lat, s=7.5, color=color)
ax.set_aspect("equal")
ax.set_axis_off()
ax.legend([f"{kiln_tech} Kilns = {total_kilns}"], loc="upper right", fontsize=10)
# ax.set_title(f"Brick Kilns in NCR (Technology: {kiln_tech})")
fig.savefig(f"../figures/ncr_kilns_{kiln_tech}.png", bbox_inches="tight", dpi=300)
plt.show()
# Out:
# 22
# 0
# 0

# %%
import matplotlib.pyplot as plt
import geopandas as gpd

# Filter the kilns within NCR boundaries using a spatial join
ncr_kilns_gdf = gpd.sjoin(all_kilns_gdf, ncr_df, how="inner")

# Separate kilns by technology and count them
CFCBK_kilns = ncr_kilns_gdf[ncr_kilns_gdf["class_name"] == "CFCBK"]
FCBK_kilns = ncr_kilns_gdf[ncr_kilns_gdf["class_name"] == "FCBK"]
Zigzag_kilns = ncr_kilns_gdf[ncr_kilns_gdf["class_name"] == "Zigzag"]
CFCBK_kilns_2 = ncr_kilns_gdf_2[ncr_kilns_gdf_2["class_name"] == "CFCBK"]
FCBK_kilns_2 = ncr_kilns_gdf_2[ncr_kilns_gdf_2["class_name"] == "FCBK"]
Zigzag_kilns_2 = ncr_kilns_gdf_2[ncr_kilns_gdf_2["class_name"] == "Zigzag"]
CFCBK_kilns_3 = ncr_kilns_gdf_3[ncr_kilns_gdf_3["class_name"] == "CFCBK"]
FCBK_kilns_3 = ncr_kilns_gdf_3[ncr_kilns_gdf_3["class_name"] == "FCBK"]
Zigzag_kilns_3 = ncr_kilns_gdf_3[ncr_kilns_gdf_3["class_name"] == "Zigzag"]


num_CFCBK = len(CFCBK_kilns)
num_FCBK = len(FCBK_kilns)
num_Zigzag = len(Zigzag_kilns)
num_CFCBK_2 = len(CFCBK_kilns_2)
num_FCBK_2 = len(FCBK_kilns_2)
num_Zigzag_2 = len(Zigzag_kilns_2)
num_CFCBK_3 = len(CFCBK_kilns_3)
num_FCBK_3 = len(FCBK_kilns_3)
num_Zigzag_3 = len(Zigzag_kilns_3)
total_fcbk = num_FCBK + num_FCBK_2 + num_FCBK_3
total_cfbck = num_CFCBK + num_CFCBK_2 + num_CFCBK_3
total_zigzag = num_Zigzag + num_Zigzag_2 + num_Zigzag_3
total_kilns = total_fcbk + total_cfbck + total_zigzag

# Print counts for confirmation
print(f"Number of CFCBK kilns: {num_CFCBK}")
print(f"Number of FCBK kilns: {num_FCBK}")
print(f"Number of Zigzag kilns: {num_Zigzag}")

# Plot
fig, ax = plt.subplots(dpi=300, figsize=(10, 10))
ncr_df.plot(ax=ax, color="none", edgecolor="black", linewidth=1)

# Scatter plot for each kiln type with counts in the legend
scatter_CFCBK = ax.scatter(CFCBK_kilns.center_lon, CFCBK_kilns.center_lat, s=5, color='red', label=f"CFCBK: {total_cfbck}")
scatter_FCBK = ax.scatter(FCBK_kilns.center_lon, FCBK_kilns.center_lat, s=5, color='orange', label=f"FCBK: {total_fcbk}")
scatter_Zigzag = ax.scatter(Zigzag_kilns.center_lon, Zigzag_kilns.center_lat, s=5, color='green', label=f"Zigzag: {total_zigzag}")
scatter_CFCBK_2 = ax.scatter(CFCBK_kilns_2.center_lon, CFCBK_kilns_2.center_lat, s=5,color='red')
scatter_FCBK_2 = ax.scatter(FCBK_kilns_2.center_lon, FCBK_kilns_2.center_lat, s=5,color='orange')
scatter_Zigzag_2 = ax.scatter(Zigzag_kilns_2.center_lon, Zigzag_kilns_2.center_lat, s=5,color='green')
scatter_CFCBK_3 = ax.scatter(CFCBK_kilns_3.center_lon, CFCBK_kilns_3.center_lat, s=5,color='red')
scatter_FCBK_3 = ax.scatter(FCBK_kilns_3.center_lon, FCBK_kilns_3.center_lat, s=5,color='orange')
scatter_Zigzag_3 = ax.scatter(Zigzag_kilns_3.center_lon, Zigzag_kilns_3.center_lat, s=5,color='green')


# Add legend with formatted labels
ax.legend( loc="upper right", fontsize=20)
# title="Kiln Technology (Count)",
# Formatting the plot
ax.set_aspect("equal")
ax.set_axis_off()

# Save the figure
fig.savefig("../figures/ncr_all_kilns_with_legend_counts.png", bbox_inches="tight", dpi=300)

plt.show()
# Out:
# Number of CFCBK kilns: 22
# Number of FCBK kilns: 278
# Number of Zigzag kilns: 3111

# %%
csv="../result_csv/ncr_kilns_count.csv"
df=pd.read_csv(csv)
#save as pdf
df.to_latex("../result_csv/ncr_kilns_count.tex", index=False)
df.head()
# Out:
#       District  CFCBK  FCBK  Zigzag
# 0        ALWAR      0    14      66
# 1      BAGHPAT      0    20     414
# 2    BHARATPUR      0    12      78
# 3      BHIWANI      0     1     108
# 4  BULANDSHAHR     11    85     283
